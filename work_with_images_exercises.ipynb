# %%
words = Image.open('word_matrix.png')

# %%
rgb_im = words.convert('RGB')
rgb_im.save('word_matrix.jpg')

# %%
mask = Image.open('mask.png')
rgb_im = mask.convert('RGB')
rgb_im.save('mask_matrix.jpg')

# %%
words = Image.open('word_matrix.jpg')
mask = Image.open('mask_matrix.jpg')

# %%
mask
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=505x251 at 0x1DABB04F130>

# %%
words
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1015x559 at 0x1DABE592280>

# %%
words.size
# Out:
# (1015, 559)

# %%
new_mask = mask.resize((1015,559))

# %%
new_mask
# Out:
# <PIL.Image.Image image mode=RGB size=1015x559 at 0x1DABCDFEFD0>

# %%
new_mask.putalpha(150)

# %%
words.paste(im=new_mask,box=(0,0),mask=new_mask)

# %%
words
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1015x559 at 0x1DABE592280>
